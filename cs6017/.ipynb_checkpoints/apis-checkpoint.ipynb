# %% [markdown]
# # Introduction to Data Science – Lecture 12 - APIs
# *COMP 5360 / MATH 4100, University of Utah, http://datasciencecourse.net/*
#
# In this lecture we will explore how we can extract data from web-APIs. The first part of this tutorial is based on [this blog](https://www.dataquest.io/blog/python-api-tutorial/).
#
# API stands for **A**pplication **P**rogramming **I**nterface. It is supposed to be a **well defined interface** for consuming data (in contrast to web-scraping), or, more generally, for the **interaction with a remote program** on a server. APIs aren't only generated so that you can read data; they're often designed so that you could write custom software to interact with the API. You could, for example, write your own twitter client!
#
# APIs are usually well documented, as the organization that provides APIs wants you to use them.
#
# Here are a couple of examples of sites that have documented APIs:
#
#  * [StackExchange](https://api.stackexchange.com/docs)
#  * [Twitter](https://dev.twitter.com/rest/public)
#  * [Facebook](https://developers.facebook.com/docs/graph-api)
#  * [KEGG](http://www.genome.jp/kegg/rest/keggapi.html)
#  * [Google Maps](https://developers.google.com/maps/)
#  * and many many more.
#
# Most APIs require some form of authentication and have rules on what you're allowed to do and what not. Follow those rules, or you will be blocked faster than you can say `GET`.
#
# An API works a lot like working with a website, but instead of a human in front of the screen, it's computers talking to each other.
#
# We'll be using the dominant form of APIs, REST (REpresentational State Transfer), which are now the dominant way of exposing and API on the web. REST APIs use an [URI](https://en.wikipedia.org/wiki/Uniform_Resource_Identifier) (a Uniform Resource Identifier; URLs are one specific form of URIs) to specify what you want to do with and API.
#
# All API methods in REST are relative to a base URL. E.g., for twitter this would be
# ```
# https://api.twitter.com/1.1/
# ```
#
# A query would look like this:
#
# ```
# https://api.twitter.com/1.1/search/tweets.json?q=%40twitterapi
# ```
#
# REST APIs can return data in different forms, the most common ones are JSON and XML, and of those two, JSON is now dominant.
#
# JSON stands for JavaScript Object Notation, and is a pretty convenient format, as we'll see.
#
#
# Let's start with a very simple example, retrieving the current position of the ISS. We will be using the [requests](https://requests.readthedocs.io/en/master/) library, which will handle our communication with the server.

# %%
import requests 
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get( "http://api.open-notify.org/iss-now.json" )

response
# Out:
# <Response [200]>

# %% [markdown]
# That looks good, we've received a response and it has status 200. What does the 200 mean? It's a status code - you've probably seen the "Error 404" on the internet.
#
# Here are a couple of codes:
#
#  * **200** – everything went okay, and the result has been returned (if any)
#  * **301** – the server is redirecting you to a different endpoint. This can happen when a company switches domain names, or an endpoint name is changed.
#  * **401** – the server thinks you’re not authenticated. This happens when you don’t send the right credentials to access an API (we’ll talk about authentication later).
#  * **400** – the server thinks you made a bad request. This can happen when you don’t send along the right data, among other things.
#  * **403** – the resource you’re trying to access is forbidden – you don’t have the right permissions to see it.
#  * **404** – the resource you tried to access wasn’t found on the server.
#
# Let's try to get a response with a wrong URL:

# %%
response_failed = requests.get("http://api.open-notify.org/iss")

response_failed
# Out:
# <Response [404]>

# %% [markdown]
# We used the get methods to put in a GET request. There are four different types of requests:
#
# ![Request types](requests.png)
# [Source](https://en.wikipedia.org/wiki/Representational_state_transfer)

# %% [markdown]
# Let's look at the payload of our previous, successful response:

# %%
response.content
# Out:
# b'{"iss_position": {"longitude": "121.7863", "latitude": "-35.9657"}, "timestamp": 1685637298, "message": "success"}'

# %% [markdown]
# We can already see that this is JSON (though it is stored a `bytes` object), but we can check formally:

# %%
response.headers['content-type']
# Out:
# 'application/json'

# %% [markdown]
# We can decode this byte object, then the JSON will be readable.

# %%
import json

response_j = response.content.decode( "utf-8" )
print( "Type: ", type( response_j ) )
print( "Value:", response_j )
# Out:
# Type:  <class 'str'>
# Value: {"timestamp": 1654064778, "iss_position": {"latitude": "43.0023", "longitude": "116.7335"}, "message": "success"}

# %% [markdown]
# Let's take a look at the JSON here:
#
# ```JSON
# {
#   "iss_position": {
#     "latitude": -30.005751854107206,
#     "longitude": -104.20085371352678
#   },
#   "message": "success",
#   "timestamp": 1475240215
# }
# ```
#
# This looks a lot like a dictionary! We have key-value pairs.
#
# We can use the [json library](https://docs.python.org/3/library/json.html) to convert JSON strings into an easy to use dictionary:

# %%
import json

# loads converts a string (that contains json data) into a dictionary
response_d = json.loads( response_j )

print( type( response_d ) )

# dumps will "pretty print" the dictionary
print( json.dumps( response_d, indent = 4 ) )

print( "position:", response_d[ "iss_position" ] )
# Out:
# <class 'dict'>
# {
#     "timestamp": 1654064778,
#     "iss_position": {
#         "latitude": "43.0023",
#         "longitude": "116.7335"
#     },
#     "message": "success"
# }
# position: {'latitude': '43.0023', 'longitude': '116.7335'}

# %% [markdown]
# Or, not surprisingly, pandas can also load a jsong object:

# %%
import pandas as pd 

df = pd.read_json( response_j )
df
# Out:
#                     timestamp  iss_position  message
# latitude  2022-06-01 06:26:18       43.0023  success
# longitude 2022-06-01 06:26:18      116.7335  success

# %% [markdown]
# This isn't quite what we want - we probably want one row per timestamp and longitude and latitude as columns:

# %%
def flatten(response_d):
    response_d["latitude"]  = response_d["iss_position"]["latitude"]
    response_d["longitude"] = response_d["iss_position"]["longitude"]
    del( response_d["iss_position"] )
    return response_d

flatten( response_d )
# Out:
# {'timestamp': 1654064778,
#  'message': 'success',
#  'latitude': '43.0023',
#  'longitude': '116.7335'}

# %% [markdown]
# That looks better. Let's get a couple of positions of the ISS over time and save it as an array:

# %%
import time

def pull_position():
    """Retreives the position of the ISS and returns it as a flat dictionary"""
    response = requests.get( "http://api.open-notify.org/iss-now.json" )
    response_j = response.content.decode( "utf-8" )
    response_d = json.loads( response_j )
    flat_response = flatten( response_d )
    return flat_response    

iss_position = []
    
# calls pull_position 10 times with 3 seconds break
for i in range( 10 ):
    flat_response = pull_position()
    iss_position.append( flat_response )
    print( flat_response )
    time.sleep( 3 )
    
len( iss_position )
# Out:
# {'timestamp': 1654065612, 'message': 'success', 'latitude': '45.5554', 'longitude': '-168.2428'}
# {'timestamp': 1654065615, 'message': 'success', 'latitude': '45.4651', 'longitude': '-168.0094'}
# {'timestamp': 1654065618, 'message': 'success', 'latitude': '45.3743', 'longitude': '-167.7771'}
# {'timestamp': 1654065621, 'message': 'success', 'latitude': '45.2830', 'longitude': '-167.5454'}
# {'timestamp': 1654065624, 'message': 'success', 'latitude': '45.1911', 'longitude': '-167.3145'}
# {'timestamp': 1654065627, 'message': 'success', 'latitude': '45.0988', 'longitude': '-167.0844'}
# {'timestamp': 1654065630, 'message': 'success', 'latitude': '45.0059', 'longitude': '-166.8551'}
# {'timestamp': 1654065633, 'message': 'success', 'latitude': '44.8970', 'longitude': '-166.5886'}
# {'timestamp': 1654065636, 'message': 'success', 'latitude': '44.8030', 'longitude': '-166.3610'}
# {'timestamp': 1654065639, 'message': 'success', 'latitude': '44.7085', 'longitude': '-166.1342'}
# 10

# %% [markdown]
# Now we can convert this into a nice dataframe:

# %%
iss_position_df = pd.DataFrame(iss_position)
iss_position_df['timestamp']  = pd.to_datetime(iss_position_df['timestamp'], unit="s")

iss_position_df = iss_position_df.set_index(pd.DatetimeIndex(iss_position_df['timestamp']))
iss_position_df["latitude"] = iss_position_df["latitude"].map(float)
iss_position_df["longitude"] = iss_position_df["longitude"].map(float)

# %% [markdown]
# Let's see how the ISS moves

# %%
import matplotlib.pyplot as plt
# This next line tells jupyter to render the images inline
# %matplotlib inline
plt.style.use('ggplot')
iss_position_df.plot(kind="scatter", x="latitude", y="longitude")
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='longitude'>

# %% [markdown]
# ### Querying with Parameters
#
# Requests can be parametrized. You can search for tweets of a specific user, for example, or [retrieve the time the ISS is over SLC](http://open-notify.org/Open-Notify-API/ISS-Pass-Times/)!
#
# The way to query with a get request for the ISS is this:
#
# `http://api.open-notify.org/iss-pass.json?lat=40.758701&lon=-111.876183`
#
# We, of course, could generate that URL ourselves, but the requests library is helpful here. Since JSON is similar to dictionaries, the requests library takes dictionaries for parameters.

# %%
from datetime import datetime

url = "http://api.open-notify.org/iss-pass.json"
coordinates = { "lat": 40.758701, "lon": -111.876183, "n": 5 }

r = requests.get( url, params=coordinates )
data = r.json()
data

# for time in data["response"]:
#     rise = time[ "risetime" ]
#     date = datetime.fromtimestamp( rise )
#     print( date )
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1654065702,
#   'latitude': 40.758701,
#   'longitude': -111.876183,
#   'passes': 5},
#  'response': [{'duration': 139, 'risetime': 1654108924},
#   {'duration': 625, 'risetime': 1654114431},
#   {'duration': 639, 'risetime': 1654120226},
#   {'duration': 570, 'risetime': 1654126111},
#   {'duration': 580, 'risetime': 1654131975}]}

# %%
timestamp = data["response"][0]["risetime"]
pd.to_datetime(timestamp,  unit="s")
# Out:
# Timestamp('2022-06-01 18:42:04')

# %% [markdown]
# So, the ISS will be visible at 6:42 PM!

# %% [markdown]
# ### Exercise: How many Astronauts?
#
# Use the [Open Notify API](http://open-notify.org/Open-Notify-API/People-In-Space/) to find out how many people are in space right now.

# %%
r = requests.get( "http://api.open-notify.org/astros.json" )
data = r.json()
data
# Out:
# {'people': [{'craft': 'ISS', 'name': 'Oleg Artemyev'},
#   {'craft': 'ISS', 'name': 'Denis Matveev'},
#   {'craft': 'ISS', 'name': 'Sergey Korsakov'},
#   {'craft': 'ISS', 'name': 'Kjell Lindgren'},
#   {'craft': 'ISS', 'name': 'Bob Hines'},
#   {'craft': 'ISS', 'name': 'Samantha Cristoforetti'},
#   {'craft': 'ISS', 'name': 'Jessica Watkins'}],
#  'message': 'success',
#  'number': 7}

# %% [markdown]
# ## Libraries and Authentication
#
# While we now have the skills to directly talk to an API, it's sometimes a little tedious. Popular APIs often have existing Python libraries that wrap around them. [Here](https://github.com/realpython/list-of-python-api-wrappers) is a long list of wrappers!
#
# Now we'll explore the Twitter API using the [twython library](https://github.com/ryanmcgrath/twython). Check out the [documentation](https://twython.readthedocs.io/en/latest/).
#
# Unfortunately, most professional APIs will require you to authenticate and will limit you in what you can do – mostly they limit how much data you can retreive at a certain time. To run the following code, you'll have to put in your own credentials (sorry – I can't share mine).
#
# Install twython:
# `pip3 install twython`
#
# * Go to https://apps.twitter.com/ and create a new app
# * Save your consumer key and consumer secret in a file `credentials.py` in the format:
# ```python
# CONSUMER_KEY = "KEY"
# CONSUMER_SECRET = "KEY"
# ACCESS_TOKEN = "KEY"
# ACCESS_TOKEN_SECRET = "KEY"
# ```
#
# But before we get started, let's check out what [a tweet looks like](https://dev.twitter.com/overview/api/tweets):

# %% [markdown]
# ```JSON
# {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Sep 30 18:37:48 +0000 2016',
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 2960,
#   'favorited': False,
#   'geo': None,
#   'id': 781926033159249920,
#   'id_str': '781926033159249920',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'retweet_count': 1283,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': "For those few people knocking me for tweeting at three o'clock in the morning, at least you know I will be there, awake, to answer the call!",
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'DonaldJTrump.com',
#        'expanded_url': 'http://www.DonaldJTrump.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/mZB2hymxC9'}]}},
#    'favourites_count': 39,
#    'follow_request_sent': None,
#    'followers_count': 11929387,
#    'following': None,
#    'friends_count': 41,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 25073877,
#    'id_str': '25073877',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 39225,
#    'location': 'New York, NY',
#    'name': 'Donald J. Trump',
#    'notifications': None,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/530021613/trump_scotland__43_of_70_cc.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/530021613/trump_scotland__43_of_70_cc.jpg',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1468988952',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1980294624/DJT_Headshot_V2_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1980294624/DJT_Headshot_V2_normal.jpg',
#    'profile_link_color': '0D5B73',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'realDonaldTrump',
#    'statuses_count': 33344,
#    'time_zone': 'Eastern Time (US & Canada)',
#    'url': 'https://t.co/mZB2hymxC9',
#    'utc_offset': -14400,
#    'verified': True}
# ```

# %%
from twython import Twython
# credentials is a local file with your own credentials. It defines CONSUMER_KEY and CONSUMER_SECRET
from credentials import * 
twitter = Twython( CONSUMER_KEY, CONSUMER_SECRET )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Ubuntu\home\dav\Classes\MSD\Summer_2022\CS6017\Examples\Week3\scrapingAndApis\apis.ipynb Cell 32' in <cell line: 4>()
#       <a href='vscode-notebook-cell://wsl%24/Ubuntu/home/dav/Classes/MSD/Summer_2022/CS6017/Examples/Week3/scrapingAndApis/apis.ipynb#ch0000031?line=1'>2</a> # credentials is a local file with your own credentials. It defines CONSUMER_KEY and CONSUMER_SECRET
#       <a href='vscode-notebook-cell://wsl%24/Ubuntu/home/dav/Classes/MSD/Summer_2022/CS6017/Examples/Week3/scrapingAndApis/apis.ipynb#ch0000031?line=2'>3</a> from credentials import *
# ----> <a href='vscode-notebook-cell://wsl%24/Ubuntu/home/dav/Classes/MSD/Summer_2022/CS6017/Examples/Week3/scrapingAndApis/apis.ipynb#ch0000031?line=3'>4</a> twitter = Twython( CONSUMER_KEY, CONSUMER_SECRET )
#
# NameError: name 'CONSUMER_KEY' is not defined

# %% [markdown]
# Here, we have created the Twython library object and authenticated against our user.
#
# Now let's search for a hashtag:

# %%
tag = "#ACNH"
result = twitter.search(q=tag, tweet_mode="extended")
result
# Out:
# pop',
#     'location': 'Beebe, AR',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 22,
#     'friends_count': 431,
#     'listed_count': 0,
#     'created_at': 'Mon Feb 08 04:41:43 +0000 2016',
#     'favourites_count': 772,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 97,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1234612218634915848/JJycgOKM_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1234612218634915848/JJycgOKM_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4886731989/1583184347',
#     'profile_link_color': '7FDBB6',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri May 28 14:03:03 +0000 2021',
#     'id': 1398278649737064449,
#     'id_str': '1398278649737064449',
#     'full_text': 'Happy Birthday to Renée! 🎉 🦏 #ACNH https://t.co/GK8kQyVVhG',
#     'truncated': False,
#     'display_text_range': [0, 34],
#     'entities': {'hashtags': [{'text': 'ACNH', 'indices': [29, 34]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1398278645215596546,
#        'id_str': '1398278645215596546',
#        'indices': [35, 58],
#        'media_url': 'http://pbs.twimg.com/media/E2evBPkXEAIHCw6.png',
#        'media_url_https': 'https://pbs.twimg.com/media/E2evBPkXEAIHCw6.png',
#        'url': 'https://t.co/GK8kQyVVhG',
#        'display_url': 'pic.twitter.com/GK8kQyVVhG',
#        'expanded_url': 'https://twitter.com/ACWorldBlog/status/1398278649737064449/photo/1',
#        'type': 'photo',
#        'sizes': {'large': {'w': 600, 'h': 600, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 600, 'h': 600, 'resize': 'fit'},
#         'small': {'w': 600, 'h': 600, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1398278645215596546,
#        'id_str': '1398278645215596546',
#        'indices': [35, 58],
#        'media_url': 'http://pbs.twimg.com/media/E2evBPkXEAIHCw6.png',
#        'media_url_https': 'https://pbs.twimg.com/media/E2evBPkXEAIHCw6.png',
#        'url': 'https://t.co/GK8kQyVVhG',
#        'display_url': 'pic.twitter.com/GK8kQyVVhG',
#        'expanded_url': 'https://twitter.com/ACWorldBlog/status/1398278649737064449/photo/1',
#        'type': 'photo',
#        'sizes': {'large': {'w': 600, 'h': 600, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 600, 'h': 600, 'resize': 'fit'},
#         'small': {'w': 600, 'h': 600, 'resize': 'fit'}}}]},
#     'metadata': {'iso_language_code': 'ht', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 517358431,
#      'id_str': '517358431',
#      'name': 'Animal Crossing World 🛩️🏝️',
#      'screen_name': 'ACWorldBlog',
#      'location': 'Canada',
#      'description': 'Bringing you news and guides for Animal Crossing: New Horizons! As an Amazon Associate, we earn from qualifying purchases. 📬 justin@animalcrossingworld.com',
#      'url': 'https://t.co/Vym2tawSzH',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/Vym2tawSzH',
#          'expanded_url': 'https://animalcrossingworld.com',
#          'display_url': 'animalcrossingworld.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 276351,
#      'friends_count': 129,
#      'listed_count': 499,
#      'created_at': 'Wed Mar 07 08:14:59 +0000 2012',
#      'favourites_count': 6338,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 6871,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'B2DFDA',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': True,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1215725105122172928/_4REuQH4_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1215725105122172928/_4REuQH4_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/517358431/1577975978',
#      'profile_link_color': '93A644',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 38,
#     'favorite_count': 456,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'ht'},
#    'is_quote_status': False,
#    'retweet_count': 38,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ht'},
#   {'created_at': 'Fri May 28 17:35:00 +0000 2021',
#    'id': 1398331988935950340,
#    'id_str': '1398331988935950340',
#    'full_text': 'RT @mushrooom___: めんつがよき。\n #どうぶつの森 #AnimalCrossing #ACNH #NintendoSwitch https://t.co/p7WmhhEnHt',
#    'truncated': False,
#    'display_text_range': [0, 96],
#    'entities': {'hashtags': [{'text': 'どうぶつの森', 'indices': [27, 34]},
#      {'text': 'AnimalCrossing', 'indices': [35, 50]},
#      {'text': 'ACNH', 'indices': [51, 56]},
#      {'text': 'NintendoSwitch', 'indices': [57, 72]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'mushrooom___',
#       'name': 'きのこちゃん',
#       'id': 1252779494298939392,
#       'id_str': '1252779494298939392',
#       'indices': [3, 16]}],
#     'urls': [],
#     'media': [{'id': 1398331850758627335,
#       'id_str': '1398331850758627335',
#       'indices': [73, 96],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1398331850758627335/pu/img/-ypuadlnmhPK-11-.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1398331850758627335/pu/img/-ypuadlnmhPK-11-.jpg',
#       'url': 'https://t.co/p7WmhhEnHt',
#       'display_url': 'pic.twitter.com/p7WmhhEnHt',
#       'expanded_url': 'https://twitter.com/mushrooom___/status/1398331879435096064/video/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#        'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#       'source_status_id': 1398331879435096064,
#       'source_status_id_str': '1398331879435096064',
#       'source_user_id': 1252779494298939392,
#       'source_user_id_str': '1252779494298939392'}]},
#    'extended_entities': {'media': [{'id': 1398331850758627335,
#       'id_str': '1398331850758627335',
#       'indices': [73, 96],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1398331850758627335/pu/img/-ypuadlnmhPK-11-.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1398331850758627335/pu/img/-ypuadlnmhPK-11-.jpg',
#       'url': 'https://t.co/p7WmhhEnHt',
#       'display_url': 'pic.twitter.com/p7WmhhEnHt',
#       'expanded_url': 'https://twitter.com/mushrooom___/status/1398331879435096064/video/1',
#       'type': 'video',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#        'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#       'source_status_id': 1398331879435096064,
#       'source_status_id_str': '1398331879435096064',
#       'source_user_id': 1252779494298939392,
#       'source_user_id_str': '1252779494298939392',
#       'video_info': {'aspect_ratio': [16, 9],
#        'duration_millis': 12000,
#        'variants': [{'bitrate': 256000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1398331850758627335/pu/vid/480x270/wwfV5JO46H85yxLq.mp4?tag=12'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/1398331850758627335/pu/pl/tpLv2MzFeUZQP-2s.m3u8?tag=12&container=fmp4'},
#         {'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1398331850758627335/pu/vid/1280x720/xosiZX0vjoifXb61.mp4?tag=12'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1398331850758627335/pu/vid/640x360/X-ir9nO1yC9qgtQo.mp4?tag=12'}]},
#       'additional_media_info': {'monetizable': False,
#        'source_user': {'id': 1252779494298939392,
#         'id_str': '1252779494298939392',
#         'name': 'きのこちゃん',
#         'screen_name': 'mushrooom___',
#         'location': 'biscuit island',
#         'description': '#animalcrossing 25↑ 🐏🌳🌲 natural / 北欧 / MOOMIN / marimekko',
#         'url': None,
#         'entities': {'description': {'urls': []}},
#         'protected': False,
#         'followers_count': 23,
#         'friends_count': 22,
#         'listed_count': 0,
#         'created_at': 'Wed Apr 22 02:01:28 +0000 2020',
#         'favourites_count': 311,
#         'utc_offset': None,
#         'time_zone': None,
#         'geo_enabled': False,
#         'verified': False,
#         'statuses_count': 562,
#         'lang': None,
#         'contributors_enabled': False,
#         'is_translator': False,
#         'is_translation_enabled': False,
#         'profile_background_color': 'F5F8FA',
#         'profile_background_image_url': None,
#         'profile_background_image_url_https': None,
#         'profile_background_tile': False,
#         'profile_image_url': 'http://pbs.twimg.com/profile_images/1261092804073316359/5m-onV3P_normal.jpg',
#         'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261092804073316359/5m-onV3P_normal.jpg',
#         'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1252779494298939392/1588747791',
#         'profile_link_color': '1DA1F2',
#         'profile_sidebar_border_color': 'C0DEED',
#         'profile_sidebar_fill_color': 'DDEEF6',
#         'profile_text_color': '333333',
#         'profile_use_background_image': True,
#         'has_extended_profile': False,
#         'default_profile': True,
#         'default_profile_image': False,
#         'following': None,
#         'follow_request_sent': None,
#         'notifications': None,
#         'translator_type': 'none',
#         'withheld_in_countries': []}}}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="https://www.labnol.org/bots" rel="nofollow">New Horizons Retweet Bot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1243530075498315777,
#     'id_str': '1243530075498315777',
#     'name': 'New Horizons Retweets',
#     'screen_name': 'acnhretweet',
#     'location': '私はオートマトンです🤖',
#     'description': 'I retweet #AnimalCrossingNewHorizons clips ♡ Follow me for ACNH content in your timeline!',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 5118,
#     'friends_count': 810,
#     'listed_count': 12,
#     'created_at': 'Fri Mar 27 13:27:42 +0000 2020',
#     'favourites_count': 85652,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 425906,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1326252583619600396/bJkJTQF7_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1326252583619600396/bJkJTQF7_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1243530075498315777/1605038232',
#     'profile_link_color': '55FF55',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri May 28 17:34:34 +0000 2021',
#     'id': 1398331879435096064,
#     'id_str': '1398331879435096064',
#     'full_text': 'めんつがよき。\n #どうぶつの森 #AnimalCrossing #ACNH #NintendoSwitch https://t.co/p7WmhhEnHt',
#     'truncated': False,
#     'display_text_range': [0, 54],
#     'entities': {'hashtags': [{'text': 'どうぶつの森', 'indices': [9, 16]},
#       {'text': 'AnimalCrossing', 'indices': [17, 32]},
#       {'text': 'ACNH', 'indices': [33, 38]},
#       {'text': 'NintendoSwitch', 'indices': [39, 54]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1398331850758627335,
#        'id_str': '1398331850758627335',
#        'indices': [55, 78],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1398331850758627335/pu/img/-ypuadlnmhPK-11-.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1398331850758627335/pu/img/-ypuadlnmhPK-11-.jpg',
#        'url': 'https://t.co/p7WmhhEnHt',
#        'display_url': 'pic.twitter.com/p7WmhhEnHt',
#        'expanded_url': 'https://twitter.com/mushrooom___/status/1398331879435096064/video/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#         'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1398331850758627335,
#        'id_str': '1398331850758627335',
#        'indices': [55, 78],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1398331850758627335/pu/img/-ypuadlnmhPK-11-.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1398331850758627335/pu/img/-ypuadlnmhPK-11-.jpg',
#        'url': 'https://t.co/p7WmhhEnHt',
#        'display_url': 'pic.twitter.com/p7WmhhEnHt',
#        'expanded_url': 'https://twitter.com/mushrooom___/status/1398331879435096064/video/1',
#        'type': 'video',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#         'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#        'video_info': {'aspect_ratio': [16, 9],
#         'duration_millis': 12000,
#         'variants': [{'bitrate': 256000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1398331850758627335/pu/vid/480x270/wwfV5JO46H85yxLq.mp4?tag=12'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/ext_tw_video/1398331850758627335/pu/pl/tpLv2MzFeUZQP-2s.m3u8?tag=12&container=fmp4'},
#          {'bitrate': 2176000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1398331850758627335/pu/vid/1280x720/xosiZX0vjoifXb61.mp4?tag=12'},
#          {'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1398331850758627335/pu/vid/640x360/X-ir9nO1yC9qgtQo.mp4?tag=12'}]},
#        'additional_media_info': {'monetizable': False}}]},
#     'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#     'source': '<a href="https://www.nintendo.com/countryselector" rel="nofollow">Nintendo Switch Share</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 1252779494298939392,
#      'id_str': '1252779494298939392',
#      'name': 'きのこちゃん',
#      'screen_name': 'mushrooom___',
#      'location': 'biscuit island',
#      'description': '#animalcrossing 25↑ 🐏🌳🌲 natural / 北欧 / MOOMIN / marimekko',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 23,
#      'friends_count': 22,
#      'listed_count': 0,
#      'created_at': 'Wed Apr 22 02:01:28 +0000 2020',
#      'favourites_count': 311,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 562,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1261092804073316359/5m-onV3P_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1261092804073316359/5m-onV3P_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1252779494298939392/1588747791',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': None,
#      'follow_request_sent': None,
#      'notifications': None,
#      'translator_type': 'none',
#      'withheld_in_countries': []},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'ja'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'}],
#  'search_metadata': {'completed_in': 0.051,
#   'max_id': 1398332305412964352,
#   'max_id_str': '1398332305412964352',
#   'next_results': '?max_id=1398331988935950339&q=%23ACNH&include_entities=1',
#   'query': '%23ACNH',
#   'refresh_url': '?since_id=1398332305412964352&q=%23ACNH&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %% [markdown]
# The result is an array of tweets, we can look at specific text:

# %%
result["statuses"][5]["full_text"]
# Out:
# '#AnimalCrossing #ACNH #NintendoSwitch https://t.co/T2giVZ6QJg'

# %% [markdown]
# Or print all the tweets:

# %%
for status in result["statuses"][:20]:
    print(status["full_text"])
    print("----")
# Out:
# RT @ephhemere_acnh: Happy Friday everyone! 🎉
#
# #acnh #AnimalCrossingNewHorizons https://t.co/9ByQojQe4O
# ----
# RT @m__ty416: 複数人から問い合せ頂いた
# 雲のマイデザ投稿しました♡⋰⋰
#
# こちらはハロスイのキキララアイテムを
# オマージュしました⌒🍬✩｡.
# キキララ家具との相性抜群です！
# よかったら是非使ってみてください💫☁️
#
# 🌛🧸MA-5258-8255-4028☁️🌈…
# ----
# RT @carbonara_acnh: finally finished this area after over six months of terraforming 🐌🌿 #acnh https://t.co/nb1NNMwowf
# ----
# garden lanterns make me happy 💫✨ #acnh https://t.co/HUHcOgMpdq
# ----
# bien techniquement sa passe large à l'endrois de mon île ou je veux le mettre au moins j'ai le schéma  #AnimalCrossing #ACNH #NintendoSwitch https://t.co/wr3NceNSsQ
# ----
# #AnimalCrossing #ACNH #NintendoSwitch https://t.co/T2giVZ6QJg
# ----
# RT @kyuubi_crossing: the museum #acnh https://t.co/xO2RCiCkEm
# ----
# RT @shiba_acnh: たーけはまだ起きていた！
# パタヤ姉さんそこから見えなくない！？
# 期待を裏切らないねぇ～w
# #あつ森 #どうぶつの森 #AnimalCrossing #ACNH #NintendoSwitch https://t.co/GJK2OifIT2
# ----
# #動物森友會 #AnimalCrossing #ACNH #NintendoSwitch https://t.co/yzhID8JHfE
# ----
# RT @autumnweeds: the sunken forest 🌲🍂
#
# #acnh #acnhinspo #acnhdesign #animalcrossing https://t.co/LBFlpeaSfc
# ----
# RT @babscrossing: 🎨 GENUINE ART GIVEAWAY 🎨
#
# Tired of waiting for cousin Redd to visit you? You can win all the genuine art (paintings + sta…
# ----
# たーけはまだ起きていた！
# パタヤ姉さんそこから見えなくない！？
# 期待を裏切らないねぇ～w
# #あつ森 #どうぶつの森 #AnimalCrossing #ACNH #NintendoSwitch https://t.co/GJK2OifIT2
# ----
# RT @PrettyOjamajo7: #AnimalCrossing #ACNH #NintendoSwitch https://t.co/7nHQaNQfNW
# ----
# RT @ACWorldBlog: Happy Birthday to Renée! 🎉 🦏 #ACNH https://t.co/GK8kQyVVhG
# ----
# RT @mushrooom___: めんつがよき。
#  #どうぶつの森 #AnimalCrossing #ACNH #NintendoSwitch https://t.co/p7WmhhEnHt
# ----

# %% [markdown]
# We can also search for tweets based on usernames:

# %%
result = twitter.search(q="@joe_exotic",  tweet_mode="extended")
for status in result["statuses"]:
    print(status["full_text"])
    print("----")
# Out:
# RT @joe_exotic: My book has been turned in. When it comes out, the world will finally know the truth because I held nothing back, so pre or…
# ----
# RT @joe_exotic: Help me out by keeping my name alive. Go support https://t.co/okRY62lSj1 @Tiger_King_Coin https://t.co/VyM2TzCnlO https://t…
# ----
# RT @joe_exotic: You tell me who must exploit Big Cats for profit, because if you can't walk in and love on them, they must hate you for som…
# ----
# @joe_exotic @Tiger_King_Coin Hey Joe how are you
# ----
# @joe_exotic @Tiger_King_Coin Support Joe, buy $TKING and soon to come, $CUB
#
# Join our friendly community to find out more: https://t.co/lq2oIM82SD https://t.co/gS5ArPbLDa
# ----
# RT @SwissAssAssin91: @joe_exotic @Tiger_King_Coin Crooked Carole!!! #JusticeForJoe
#
# @Tiger_King_Coin $TKing $Cub
# ----
# RT @joe_exotic: You tell me who must exploit Big Cats for profit, because if you can't walk in and love on them, they must hate you for som…
# ----
# @joe_exotic @Tiger_King_Coin The picture is just so wholesome
# ----
# @joe_exotic @Tiger_King_Coin Thank you. Much appreciated.
# ----
# @joe_exotic @Tiger_King_Coin Any chance of a follow back please @joe_exotic
# ----
# RT @joe_exotic: You tell me who must exploit Big Cats for profit, because if you can't walk in and love on them, they must hate you for som…
# ----
# RT @joe_exotic: You tell me who must exploit Big Cats for profit, because if you can't walk in and love on them, they must hate you for som…
# ----
# RT @joe_exotic: You tell me who must exploit Big Cats for profit, because if you can't walk in and love on them, they must hate you for som…
# ----
# RT @joe_exotic: You tell me who must exploit Big Cats for profit, because if you can't walk in and love on them, they must hate you for som…
# ----
# @joe_exotic @Tiger_King_Coin Crooked Carole!!! #JusticeForJoe
#
# @Tiger_King_Coin $TKing $Cub
# ----

# %% [markdown]
# This returns all tweets that are mentioning a username. We can also explicitly get the tweets of a person. Let's download the Tiger King's last 50 tweets. [Here](https://dev.twitter.com/rest/reference/get/statuses/user_timeline) is the relevant API documentation, [here](https://github.com/ryanmcgrath/twython/blob/master/twython/endpoints.py) are the definitions for twython.

# %%
#twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET, ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

# count is limited to the last 3200 tweets of a user, a max of 200 per request
tk_result = twitter.get_user_timeline(screen_name="joe_exotic", count=50)
tk_result
# Out:
# 'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 12,
#   'favorite_count': 134,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu May 13 16:56:06 +0000 2021',
#   'id': 1392886382465540096,
#   'id_str': '1392886382465540096',
#   'text': 'My attorney @JohnPhillips has worked his ass off to get me out of here and is so close to the big parade...Continue… https://t.co/LjFK8nzK3w',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'JohnPhillips',
#      'name': 'John M. Phillips',
#      'id': 58685588,
#      'id_str': '58685588',
#      'indices': [12, 25]}],
#    'urls': [{'url': 'https://t.co/LjFK8nzK3w',
#      'expanded_url': 'https://twitter.com/i/web/status/1392886382465540096',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2283789074,
#    'id_str': '2283789074',
#    'name': 'Joe Exotic',
#    'screen_name': 'joe_exotic',
#    'location': 'Fort Worth, TX',
#    'description': 'Official account for Joe Exotic 🐅 Joe’s Petitionhttps://www.change.org/JusticeForJoeExoticP Official Store https://t.co/5HlokTOucv',
#    'url': 'https://t.co/WSaLrV97r4',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/WSaLrV97r4',
#        'expanded_url': 'http://www.youtube.com/joeexotictv',
#        'display_url': 'youtube.com/joeexotictv',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/5HlokTOucv',
#        'expanded_url': 'http://www.JoeExoticUSA.com',
#        'display_url': 'JoeExoticUSA.com',
#        'indices': [107, 130]}]}},
#    'protected': False,
#    'followers_count': 58151,
#    'friends_count': 5584,
#    'listed_count': 35,
#    'created_at': 'Thu Jan 09 16:11:21 +0000 2014',
#    'favourites_count': 6366,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 13879,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1394864715885686788/FUBO9qtA_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1394864715885686788/FUBO9qtA_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2283789074/1612893885',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 7,
#   'favorite_count': 67,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu May 13 14:20:38 +0000 2021',
#   'id': 1392847255653212160,
#   'id_str': '1392847255653212160',
#   'text': 'More from Joe on Carole and the Big Cat Safety Act https://t.co/2ovsxZkvfB',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 1392847153681379330,
#      'id_str': '1392847153681379330',
#      'indices': [51, 74],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1392847153681379330/pu/img/e4Ztnco1eZ2_KJPT.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1392847153681379330/pu/img/e4Ztnco1eZ2_KJPT.jpg',
#      'url': 'https://t.co/2ovsxZkvfB',
#      'display_url': 'pic.twitter.com/2ovsxZkvfB',
#      'expanded_url': 'https://twitter.com/joe_exotic/status/1392847255653212160/video/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 900, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 960, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 510, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1392847153681379330,
#      'id_str': '1392847153681379330',
#      'indices': [51, 74],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1392847153681379330/pu/img/e4Ztnco1eZ2_KJPT.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1392847153681379330/pu/img/e4Ztnco1eZ2_KJPT.jpg',
#      'url': 'https://t.co/2ovsxZkvfB',
#      'display_url': 'pic.twitter.com/2ovsxZkvfB',
#      'expanded_url': 'https://twitter.com/joe_exotic/status/1392847255653212160/video/1',
#      'type': 'video',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 900, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 960, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 510, 'resize': 'fit'}},
#      'video_info': {'aspect_ratio': [4, 3],
#       'duration_millis': 45002,
#       'variants': [{'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1392847153681379330/pu/vid/960x720/6epnFSoivbZInt-t.mp4?tag=12'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1392847153681379330/pu/vid/480x360/l-yU9e9zrEVHf0RL.mp4?tag=12'},
#        {'bitrate': 256000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1392847153681379330/pu/vid/360x270/YGmoNVQHwhxcSW2x.mp4?tag=12'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/1392847153681379330/pu/pl/OFhcqDsIlBiouyr5.m3u8?tag=12'}]},
#      'additional_media_info': {'monetizable': False}}]},
#   'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2283789074,
#    'id_str': '2283789074',
#    'name': 'Joe Exotic',
#    'screen_name': 'joe_exotic',
#    'location': 'Fort Worth, TX',
#    'description': 'Official account for Joe Exotic 🐅 Joe’s Petitionhttps://www.change.org/JusticeForJoeExoticP Official Store https://t.co/5HlokTOucv',
#    'url': 'https://t.co/WSaLrV97r4',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/WSaLrV97r4',
#        'expanded_url': 'http://www.youtube.com/joeexotictv',
#        'display_url': 'youtube.com/joeexotictv',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/5HlokTOucv',
#        'expanded_url': 'http://www.JoeExoticUSA.com',
#        'display_url': 'JoeExoticUSA.com',
#        'indices': [107, 130]}]}},
#    'protected': False,
#    'followers_count': 58151,
#    'friends_count': 5584,
#    'listed_count': 35,
#    'created_at': 'Thu Jan 09 16:11:21 +0000 2014',
#    'favourites_count': 6366,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 13879,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1394864715885686788/FUBO9qtA_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1394864715885686788/FUBO9qtA_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2283789074/1612893885',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 6,
#   'favorite_count': 36,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed May 12 23:25:34 +0000 2021',
#   'id': 1392622004809895936,
#   'id_str': '1392622004809895936',
#   'text': '@steven5573 Sorry, domestic shipping only',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'steven5573',
#      'name': 'just me !!!',
#      'id': 75872996,
#      'id_str': '75872996',
#      'indices': [0, 11]}],
#    'urls': []},
#   'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#   'in_reply_to_status_id': 1392605041345929226,
#   'in_reply_to_status_id_str': '1392605041345929226',
#   'in_reply_to_user_id': 75872996,
#   'in_reply_to_user_id_str': '75872996',
#   'in_reply_to_screen_name': 'steven5573',
#   'user': {'id': 2283789074,
#    'id_str': '2283789074',
#    'name': 'Joe Exotic',
#    'screen_name': 'joe_exotic',
#    'location': 'Fort Worth, TX',
#    'description': 'Official account for Joe Exotic 🐅 Joe’s Petitionhttps://www.change.org/JusticeForJoeExoticP Official Store https://t.co/5HlokTOucv',
#    'url': 'https://t.co/WSaLrV97r4',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/WSaLrV97r4',
#        'expanded_url': 'http://www.youtube.com/joeexotictv',
#        'display_url': 'youtube.com/joeexotictv',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/5HlokTOucv',
#        'expanded_url': 'http://www.JoeExoticUSA.com',
#        'display_url': 'JoeExoticUSA.com',
#        'indices': [107, 130]}]}},
#    'protected': False,
#    'followers_count': 58151,
#    'friends_count': 5584,
#    'listed_count': 35,
#    'created_at': 'Thu Jan 09 16:11:21 +0000 2014',
#    'favourites_count': 6366,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 13879,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1394864715885686788/FUBO9qtA_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1394864715885686788/FUBO9qtA_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2283789074/1612893885',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 2,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed May 12 23:24:55 +0000 2021',
#   'id': 1392621840548470785,
#   'id_str': '1392621840548470785',
#   'text': '#JusticeForJoeExotic #TigerKing #JoeExotic https://t.co/j1NEHj6mOu',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'JusticeForJoeExotic',
#      'indices': [0, 20]},
#     {'text': 'TigerKing', 'indices': [21, 31]},
#     {'text': 'JoeExotic', 'indices': [32, 42]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 1392621835582386178,
#      'id_str': '1392621835582386178',
#      'indices': [43, 66],
#      'media_url': 'http://pbs.twimg.com/media/E1OWLlhXMAIOGxB.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/E1OWLlhXMAIOGxB.jpg',
#      'url': 'https://t.co/j1NEHj6mOu',
#      'display_url': 'pic.twitter.com/j1NEHj6mOu',
#      'expanded_url': 'https://twitter.com/joe_exotic/status/1392621840548470785/photo/1',
#      'type': 'photo',
#      'sizes': {'medium': {'w': 1055, 'h': 1200, 'resize': 'fit'},
#       'small': {'w': 598, 'h': 680, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1059, 'h': 1204, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1392621835582386178,
#      'id_str': '1392621835582386178',
#      'indices': [43, 66],
#      'media_url': 'http://pbs.twimg.com/media/E1OWLlhXMAIOGxB.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/E1OWLlhXMAIOGxB.jpg',
#      'url': 'https://t.co/j1NEHj6mOu',
#      'display_url': 'pic.twitter.com/j1NEHj6mOu',
#      'expanded_url': 'https://twitter.com/joe_exotic/status/1392621840548470785/photo/1',
#      'type': 'photo',
#      'sizes': {'medium': {'w': 1055, 'h': 1200, 'resize': 'fit'},
#       'small': {'w': 598, 'h': 680, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1059, 'h': 1204, 'resize': 'fit'}}}]},
#   'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2283789074,
#    'id_str': '2283789074',
#    'name': 'Joe Exotic',
#    'screen_name': 'joe_exotic',
#    'location': 'Fort Worth, TX',
#    'description': 'Official account for Joe Exotic 🐅 Joe’s Petitionhttps://www.change.org/JusticeForJoeExoticP Official Store https://t.co/5HlokTOucv',
#    'url': 'https://t.co/WSaLrV97r4',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/WSaLrV97r4',
#        'expanded_url': 'http://www.youtube.com/joeexotictv',
#        'display_url': 'youtube.com/joeexotictv',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/5HlokTOucv',
#        'expanded_url': 'http://www.JoeExoticUSA.com',
#        'display_url': 'JoeExoticUSA.com',
#        'indices': [107, 130]}]}},
#    'protected': False,
#    'followers_count': 58151,
#    'friends_count': 5584,
#    'listed_count': 35,
#    'created_at': 'Thu Jan 09 16:11:21 +0000 2014',
#    'favourites_count': 6366,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 13879,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1394864715885686788/FUBO9qtA_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1394864715885686788/FUBO9qtA_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2283789074/1612893885',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 4,
#   'favorite_count': 49,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'und'},
#  {'created_at': 'Wed May 12 23:02:50 +0000 2021',
#   'id': 1392616283578015745,
#   'id_str': '1392616283578015745',
#   'text': 'I have confirmation that my letter of evidence and proof of perjury, obstruction and suppressing evidence has been… https://t.co/gIvJilrCgM',
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/gIvJilrCgM',
#      'expanded_url': 'https://twitter.com/i/web/status/1392616283578015745',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [116, 139]}]},
#   'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2283789074,
#    'id_str': '2283789074',
#    'name': 'Joe Exotic',
#    'screen_name': 'joe_exotic',
#    'location': 'Fort Worth, TX',
#    'description': 'Official account for Joe Exotic 🐅 Joe’s Petitionhttps://www.change.org/JusticeForJoeExoticP Official Store https://t.co/5HlokTOucv',
#    'url': 'https://t.co/WSaLrV97r4',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/WSaLrV97r4',
#        'expanded_url': 'http://www.youtube.com/joeexotictv',
#        'display_url': 'youtube.com/joeexotictv',
#        'indices': [0, 23]}]},
#     'description': {'urls': [{'url': 'https://t.co/5HlokTOucv',
#        'expanded_url': 'http://www.JoeExoticUSA.com',
#        'display_url': 'JoeExoticUSA.com',
#        'indices': [107, 130]}]}},
#    'protected': False,
#    'followers_count': 58151,
#    'friends_count': 5584,
#    'listed_count': 35,
#    'created_at': 'Thu Jan 09 16:11:21 +0000 2014',
#    'favourites_count': 6366,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 13879,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1394864715885686788/FUBO9qtA_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1394864715885686788/FUBO9qtA_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2283789074/1612893885',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 14,
#   'favorite_count': 143,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'}]

# %% [markdown]
# Let's count the numbers for the Joe_Exotic's favorites and retweets.

# %%
tk_favorites = []
tk_retweets = []
for status in tk_result:
    print(status["text"])
    print(status["favorite_count"])
    print("----")
    tk_favorites.append(status["favorite_count"])
    tk_retweets.append(status["retweet_count"])
# Out:
# @UbelikeMOE @GalleryBooks We’re hoping Joe will be allowed to sign some books
# 0
# ----
# @ahodge206 @GalleryBooks Amazon is taking pre orders...Thank you!
# 0
# ----
# You tell me who must exploit Big Cats for profit, because if you can't walk in and love on them, they must hate you… https://t.co/xSnAIcKN4Y
# 52
# ----
# Now thru Memorial Day, save 25% off everything with promo code: MEMORIALDAY at the ONLY Joe Exotic Memorabilia Stor… https://t.co/XjZTK9HdGS
# 18
# ----
# My book has been turned in. When it comes out, the world will finally know the truth because I held nothing back, s… https://t.co/btMRqrB76I
# 45
# ----
# My Official Tiger King coins will help me fix children’s smiles/faces, fight justice and prison reform, and save an… https://t.co/UxJkwXqx5t
# 42
# ----
# As the world fights for the truth for Don Lewis, I pray the world will continue to fight to clear my name as well.… https://t.co/UCQXvLSXGP
# 52
# ----
# https://t.co/okRY62lSj1 @Tiger_King_Coin https://t.co/VyM2TzCnlO https://t.co/7ZXaYxa9Md
# 55
# ----
# #JusticeForJoeExotic https://t.co/okRY62lSj1 @Tiger_King_Coin https://t.co/VyM2TzCnlO https://t.co/osYlkd8UND
# 32
# ----
# ...His are 8 foot, of hog wire. Reeks of corruption.
#
# https://t.co/okRY62lSj1 @Tiger_King_Coin https://t.co/2ZVyXi2Lmf
# 18
# ----
# PeTA and Carole are taking our shit away and giving it to them. Notice no shade, and our cages had to be 14 foot wi… https://t.co/Z26TdrDNfb
# 21
# ----
# ... obstruction of justice in my case for PeTA and Carole, just to put me here for that Big Cat Bill. Then ask Bide… https://t.co/7fOyw8T0jQ
# 14
# ----
# Governor Stitt:
#
# Please talk to my attorney John Phillips and listen to the corruption we have on tapes of the Fede… https://t.co/XMakGBuKfs
# 22
# ----
# Help me out by keeping my name alive. Go support https://t.co/okRY62lSj1 @Tiger_King_Coin https://t.co/VyM2TzCnlO https://t.co/ncAWcUHAdC
# 90
# ----
# I want to know why Erik Cowie is not charged with Federal animal abuse charges? He was the man paid to care for the… https://t.co/d3OjV3yWz6
# 47
# ----
# I hope she grows up to remember me, I miss her so much
#
# https://t.co/okRY62lSj1 https://t.co/fMHh7mMrrb
# 261
# ----
# https://t.co/okRY62Dtaz https://t.co/2ZVyXhL9XF
# 10
# ----
# Scam Alert...I bet she bought them for a rescue story. I have the receipt where she bought the 56 babies and left t… https://t.co/yX5638xjEb
# 44
# ----
# Another one just fell from the Tiger King tree. Where the hell did Netflix find these dumbasses for their movie?
#
# https://t.co/VfSDjirZ5Q
# 27
# ----
# All Carole has to do is listen. I said get your authorities down here to Listen. #JusticeForJoeExotic #tigerking… https://t.co/Cuqgu5Ji2v
# 52
# ----
# https://t.co/okRY62lSj1
#
# #JusticeForJoeExotic @tiger_king_coin https://t.co/lhg5vLXAAq
# 7
# ----
# ATTENTION REPORTERS:
#
# I have been in prison dying slowly at the hands of the Government. I have nothing to do with… https://t.co/zC4XwTR7Mf
# 42
# ----
# And to celebrate the new Tiger King Crypto Coin, use Promo Code: $TKING and get 20% off all orders.
# #tigerking… https://t.co/NYXkaLJOXD
# 22
# ----
# Anyone who wants to donate to my commissary, please shop at https://t.co/okRY62lSj1 and get a Joe Exotic memorabili… https://t.co/riqrANo3tx
# 31
# ----
# I am curious how President Biden is going to react when my attorney John Phillips dominates the media with the proo… https://t.co/hNU89KxeAW
# 95
# ----
# I hope Ted Cruz wipes his ass with this Bill because Carole and her friends want to be the only owners of tigers.
#
# https://t.co/NnTYxX47Ut
# 50
# ----
# Our U.S. Attorney should learn from him
#
# https://t.co/5j9NkG4FAS
# 7
# ----
# A cold front is coming, I think hell is about to freeze over for Agent Bryant and an Asst. U.S. Attorney.… https://t.co/iMGMwfgWCK
# 50
# ----
# https://t.co/VgcmxLq2hU
# 477
# ----
# ...and obstruction of Justice, and an example made out of them. They are the reason the system is broken and every… https://t.co/pEcIXPA2zR
# 26
# ----
# At this point in my life I don't give a rat’s ass if I live or die from all of this. The one thing I want the world… https://t.co/9kh4QON1tF
# 58
# ----
# https://t.co/SAzvIxbMLS
# 80
# ----
# I am proud to endorse Tiger King official digital coins for the benefit of justice, proving innocence and fighting… https://t.co/QmMSbQ6bsY
# 105
# ----
# RT @JohnPhillips: Ending the day with some positive @joe_exotic affirmations. Tomorrow is going to be an interesting day in our investigati…
# 0
# ----
# Thank you everyone for the thoughts and prayers and the support. I can only hope this ends soon somehow some way. P… https://t.co/ZtAXIgWmPw
# 36
# ----
# Prison rules: White paper only, one sided only, 5 pages max. Do not include stamps, cards, drawings or photos. He c… https://t.co/OjpsDfVzsl
# 32
# ----
# HEALTH UPDATE: The urologist appt on June 1 has been moved to today. Now more than ever Joe needs to hear your word… https://t.co/kRCg4lpgoz
# 75
# ----
# There is a show coming out “Joe Exotic” starring John Cameron Mitchell, a Manny O Productions show, and a sleezy Ti… https://t.co/8eVoGdkbgD
# 73
# ----
# https://t.co/Ekbkx4gsWv
# 91
# ----
# My LA attorney says the movie about me starring Nicolas Cage has been cancelled. While he is a talented actor and m… https://t.co/UPVrfy8r0h
# 224
# ----
# Update:  I have an appointment on the 27th with the oncologist and June 1 with the urologist. Now they report a bio… https://t.co/Mq3qjPVm1K
# 186
# ----
# ...from all over the world. I love you all. Wish me luck...#JusticeForJoeExotic #TigerKing #JoeExotic @JohnPhillips
# 70
# ----
# ...it’s not just city cops out of control with corruption, but his very own Department of Justice and make this rig… https://t.co/vm76c8xGuv
# 50
# ----
# ...are out of control, I throw up more than I eat. I don't want anyone's pity, what I need is when John Phillips ge… https://t.co/DnulQr5AY6
# 34
# ----
# John Phillips has received my medical records from FMC Fort Worth and my PSA count came back very high for prostate… https://t.co/y1AosZuiu3
# 134
# ----
# My attorney @JohnPhillips has worked his ass off to get me out of here and is so close to the big parade...Continue… https://t.co/LjFK8nzK3w
# 67
# ----
# More from Joe on Carole and the Big Cat Safety Act https://t.co/2ovsxZkvfB
# 36
# ----
# @steven5573 Sorry, domestic shipping only
# 2
# ----
# #JusticeForJoeExotic #TigerKing #JoeExotic https://t.co/j1NEHj6mOu
# 49
# ----
# I have confirmation that my letter of evidence and proof of perjury, obstruction and suppressing evidence has been… https://t.co/gIvJilrCgM
# 143
# ----

# %% [markdown]
# Now let's do the same for ACNH.

# %%
acnh_results = twitter.get_user_timeline(screen_name="animalcrossing", count=50)
acnh_results
# Out:
# tributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '7CC1EA',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1369749495181766656/K7Vp6cxH_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1369749495181766656/K7Vp6cxH_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1377451009/1615408704',
#    'profile_link_color': '91C9EA',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 1303,
#   'favorite_count': 17146,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Fri Mar 05 14:01:16 +0000 2021',
#   'id': 1367837619221110785,
#   'id_str': '1367837619221110785',
#   'text': "[Video]\nThe snow is melting and the grass is getting greener! Here's what you can expect as you march into Spring t… https://t.co/iyiVvNks2v",
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/iyiVvNks2v',
#      'expanded_url': 'https://twitter.com/i/web/status/1367837619221110785',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://prod1.sprinklr.com" rel="nofollow">Sprinklr Publishing</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1377451009,
#    'id_str': '1377451009',
#    'name': 'Isabelle',
#    'screen_name': 'animalcrossing',
#    'location': 'Resident Services',
#    'description': 'Welcome to Animal Crossing: New Horizons! Learn more about the Deserted Island Getaway Package from Isabelle!',
#    'url': 'https://t.co/icR8OjzVtz',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/icR8OjzVtz',
#        'expanded_url': 'http://animal-crossing.com/new-horizons',
#        'display_url': 'animal-crossing.com/new-horizons',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1359525,
#    'friends_count': 3,
#    'listed_count': 1923,
#    'created_at': 'Wed Apr 24 16:28:27 +0000 2013',
#    'favourites_count': 0,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 1570,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '7CC1EA',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1369749495181766656/K7Vp6cxH_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1369749495181766656/K7Vp6cxH_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1377451009/1615408704',
#    'profile_link_color': '91C9EA',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 1557,
#   'favorite_count': 14814,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Mar 04 22:02:34 +0000 2021',
#   'id': 1367596355842043905,
#   'id_str': '1367596355842043905',
#   'text': 'RT @NintendoAmerica: Invite some new residents to Photopia on Harv’s Island for a photo shoot! After downloading the update on 3/18, you’ll…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'NintendoAmerica',
#      'name': 'Nintendo of America',
#      'id': 5162861,
#      'id_str': '5162861',
#      'indices': [3, 19]}],
#    'urls': []},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1377451009,
#    'id_str': '1377451009',
#    'name': 'Isabelle',
#    'screen_name': 'animalcrossing',
#    'location': 'Resident Services',
#    'description': 'Welcome to Animal Crossing: New Horizons! Learn more about the Deserted Island Getaway Package from Isabelle!',
#    'url': 'https://t.co/icR8OjzVtz',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/icR8OjzVtz',
#        'expanded_url': 'http://animal-crossing.com/new-horizons',
#        'display_url': 'animal-crossing.com/new-horizons',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1359525,
#    'friends_count': 3,
#    'listed_count': 1923,
#    'created_at': 'Wed Apr 24 16:28:27 +0000 2013',
#    'favourites_count': 0,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 1570,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '7CC1EA',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1369749495181766656/K7Vp6cxH_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1369749495181766656/K7Vp6cxH_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1377451009/1615408704',
#    'profile_link_color': '91C9EA',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Thu Mar 04 22:00:02 +0000 2021',
#    'id': 1367595716202356742,
#    'id_str': '1367595716202356742',
#    'text': 'Invite some new residents to Photopia on Harv’s Island for a photo shoot! After downloading the update on 3/18, you… https://t.co/9ToCGChOZl',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/9ToCGChOZl',
#       'expanded_url': 'https://twitter.com/i/web/status/1367595716202356742',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="https://prod1.sprinklr.com" rel="nofollow">Sprinklr Publishing</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 5162861,
#     'id_str': '5162861',
#     'name': 'Nintendo of America',
#     'screen_name': 'NintendoAmerica',
#     'location': '',
#     'description': 'Welcome to the official Nintendo profile for gaming news! We’re listening, too. For ESRB ratings go to https://t.co/OgSR65P8OY',
#     'url': 'https://t.co/KV95CnwR7H',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/KV95CnwR7H',
#         'expanded_url': 'https://www.nintendo.com',
#         'display_url': 'nintendo.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/OgSR65P8OY',
#         'expanded_url': 'http://esrb.org',
#         'display_url': 'esrb.org',
#         'indices': [103, 126]}]}},
#     'protected': False,
#     'followers_count': 11331460,
#     'friends_count': 227,
#     'listed_count': 14865,
#     'created_at': 'Wed Apr 18 22:43:15 +0000 2007',
#     'favourites_count': 306,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 21010,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'ACDED6',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1363208451153821701/1VN0f5aI_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1363208451153821701/1VN0f5aI_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/5162861/1621618099',
#     'profile_link_color': 'E60012',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'F6F6F6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 670,
#    'favorite_count': 6453,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 670,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Mar 03 19:05:58 +0000 2021',
#   'id': 1367189526238535680,
#   'id_str': '1367189526238535680',
#   'text': 'RT @NintendoAmerica: The Shamrock soda, shamrock doorplate, and shamrock rug items will be available from 3/10 to 3/17. One item in the ser…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'NintendoAmerica',
#      'name': 'Nintendo of America',
#      'id': 5162861,
#      'id_str': '5162861',
#      'indices': [3, 19]}],
#    'urls': []},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1377451009,
#    'id_str': '1377451009',
#    'name': 'Isabelle',
#    'screen_name': 'animalcrossing',
#    'location': 'Resident Services',
#    'description': 'Welcome to Animal Crossing: New Horizons! Learn more about the Deserted Island Getaway Package from Isabelle!',
#    'url': 'https://t.co/icR8OjzVtz',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/icR8OjzVtz',
#        'expanded_url': 'http://animal-crossing.com/new-horizons',
#        'display_url': 'animal-crossing.com/new-horizons',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1359525,
#    'friends_count': 3,
#    'listed_count': 1923,
#    'created_at': 'Wed Apr 24 16:28:27 +0000 2013',
#    'favourites_count': 0,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 1570,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '7CC1EA',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1369749495181766656/K7Vp6cxH_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1369749495181766656/K7Vp6cxH_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1377451009/1615408704',
#    'profile_link_color': '91C9EA',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Mar 03 19:00:02 +0000 2021',
#    'id': 1367188031027875843,
#    'id_str': '1367188031027875843',
#    'text': 'The Shamrock soda, shamrock doorplate, and shamrock rug items will be available from 3/10 to 3/17. One item in the… https://t.co/vpogQ0tJQQ',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/vpogQ0tJQQ',
#       'expanded_url': 'https://twitter.com/i/web/status/1367188031027875843',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'source': '<a href="https://prod1.sprinklr.com" rel="nofollow">Sprinklr Publishing</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 5162861,
#     'id_str': '5162861',
#     'name': 'Nintendo of America',
#     'screen_name': 'NintendoAmerica',
#     'location': '',
#     'description': 'Welcome to the official Nintendo profile for gaming news! We’re listening, too. For ESRB ratings go to https://t.co/OgSR65P8OY',
#     'url': 'https://t.co/KV95CnwR7H',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/KV95CnwR7H',
#         'expanded_url': 'https://www.nintendo.com',
#         'display_url': 'nintendo.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/OgSR65P8OY',
#         'expanded_url': 'http://esrb.org',
#         'display_url': 'esrb.org',
#         'indices': [103, 126]}]}},
#     'protected': False,
#     'followers_count': 11331460,
#     'friends_count': 227,
#     'listed_count': 14865,
#     'created_at': 'Wed Apr 18 22:43:15 +0000 2007',
#     'favourites_count': 306,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 21010,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'ACDED6',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1363208451153821701/1VN0f5aI_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1363208451153821701/1VN0f5aI_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/5162861/1621618099',
#     'profile_link_color': 'E60012',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'F6F6F6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1293,
#    'favorite_count': 11302,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 1293,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Mar 03 17:42:15 +0000 2021',
#   'id': 1367168455124914183,
#   'id_str': '1367168455124914183',
#   'text': "Happy Hinamatsuri, everyone! This is always one of my favorite events, so I'd love to hear about it if you're doing… https://t.co/CsQeLY3oJf",
#   'truncated': True,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/CsQeLY3oJf',
#      'expanded_url': 'https://twitter.com/i/web/status/1367168455124914183',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'source': '<a href="https://prod1.sprinklr.com" rel="nofollow">Sprinklr Publishing</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1377451009,
#    'id_str': '1377451009',
#    'name': 'Isabelle',
#    'screen_name': 'animalcrossing',
#    'location': 'Resident Services',
#    'description': 'Welcome to Animal Crossing: New Horizons! Learn more about the Deserted Island Getaway Package from Isabelle!',
#    'url': 'https://t.co/icR8OjzVtz',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/icR8OjzVtz',
#        'expanded_url': 'http://animal-crossing.com/new-horizons',
#        'display_url': 'animal-crossing.com/new-horizons',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1359525,
#    'friends_count': 3,
#    'listed_count': 1923,
#    'created_at': 'Wed Apr 24 16:28:27 +0000 2013',
#    'favourites_count': 0,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': True,
#    'statuses_count': 1570,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '7CC1EA',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1369749495181766656/K7Vp6cxH_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1369749495181766656/K7Vp6cxH_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1377451009/1615408704',
#    'profile_link_color': '91C9EA',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 1542,
#   'favorite_count': 19571,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'}]

# %%
acnh_favorites = []
acnh_retweets = []
for status in acnh_results:
    print(status["text"])
    print(status["favorite_count"])
    print("----")
    acnh_favorites.append(status["favorite_count"])
    acnh_retweets.append(status["retweet_count"])
# Out:
# Hello! Did you know that there's a silly event in England where folks roll a wheel of cheese down a hill and then c… https://t.co/puN5fYJQBl
# 17704
# ----
# Hello! I have a fun fact for you—today is International Museum Day! We're celebrating by hosting a special event at… https://t.co/GfDPopWpDF
# 15022
# ----
# RT @NintendoAmerica: Redeem your #MyNintendo Platinum Points for a chance to win a pair of adorable pals—now with new winter outfits—from t…
# 0
# ----
# RT @buildabear: Create a world of your own alongside our @animalcrossing™: New Horizons plush friends! Our Tom Nook and Isabelle bundles co…
# 0
# ----
# Hi! I just wanted to let you know that today is Children's Day...and also remind you that all of the related limite… https://t.co/YYDm9VE3Yu
# 9103
# ----
# [Announcement]
# Ninten Island, the official Nintendo #AnimalCrossing: New Horizons island, has been updated. Use the… https://t.co/Z4QliF54T6
# 15982
# ----
# Happy May, everyone! I'm sure I don't have to remind you when Mother's Day is, but Nook's Cranny has some great Mot… https://t.co/Vo2rmMMIW3
# 10082
# ----
# Hello! Are you ready for a mini vacation? I hope so, because we've got one planned for you! Just stop by the airpor… https://t.co/B44YHkxeLk
# 14837
# ----
# Hi, everyone! We're almost at the end of April, and Nook Shopping is gearing up for May with some fun Children's Da… https://t.co/gBMu7xRrHI
# 11287
# ----
# [Announcement]
# Seasonal events with new twists are on the way! Learn more about the next free update for… https://t.co/4baYMbWHPp
# 22303
# ----
# RT @NintendoAmerica: It’s prom night in #AnimalCrossing: New Horizons! Special guests @kungfufruitcup and @Stephen_Georg join Kit &amp; Krysta…
# 0
# ----
# RT @NintendoAmerica: Redeem your #MyNintendo Platinum Points for a chance to win this pair of adorable pals from the new #AnimalCrossing: N…
# 0
# ----
# Hello, friends! I wanted to let you know that Nature Day is coming up on April 22nd, and Nook Shopping is offering… https://t.co/MbaQ8aoNaP
# 16699
# ----
# [Announcement]
# Today marks the 20th anniversary of the #AnimalCrossing series! What are your favorite memories? Tha… https://t.co/3vunKDhEPA
# 42039
# ----
# RT @NintendoAmerica: Get ready for the #AnimalCrossing: New Horizons collection from @buildabear, launching tomorrow! Sign up for email upd…
# 0
# ----
# Happy Bunny Day! Have you seen Zipper yet? I know he's around here somewhere... Anyway, I hope you have fun collect… https://t.co/n1CnCTHCXb
# 17771
# ----
# [Video]
# Revel in spring with discoveries coming to your island in the month of April! Enjoy the beauty of Cherry bl… https://t.co/dL2vAKsAHv
# 11036
# ----
# Oh, and speaking of prom...you'll also find some party-perfect new costumes at the Tailors. Sounds like an excuse t… https://t.co/OwDK9RD4Jy
# 6134
# ----
# Happy April, everyone! We're starting the month off with some new seasonal items at Nook Shopping—including Singmog… https://t.co/t1OhmRv5HG
# 15565
# ----
# [Announcement]
# NookLink, which can be found on the smart device app #NintendoSwitchOnline, has been updated. Collec… https://t.co/wVADGs87qN
# 14860
# ----
# Oh, I almost forgot! Nook's Cranny also has some fun Bunny Day items in stock from now through the event. The selec… https://t.co/e9W5Hzg9Ou
# 14176
# ----
# Hello! Did you know that Bunny Day is on a different date every year? This year, it's on April 4th—that's next Sund… https://t.co/lKFQVmE2Rv
# 23505
# ----
# Hey, everyone! Can you believe March is already over? Just kidding! I'm getting warmed up for April Fools' Day, whi… https://t.co/TCMmChVLAC
# 11724
# ----
# [Announcement]
# The #AnimalCrossing @Sanrio Collaboration Pack amiibo cards are available starting today! Use them w… https://t.co/yQAZe1lYpg
# 14796
# ----
# [Announcement]
# The #AnimalCrossing: New Horizons Island Tour Creator website is now available! Show off your island… https://t.co/zThZfisthu
# 15276
# ----
# RT @Pocket_Camp: O-oh my goodness! It looks like @HelloKitty and friends are coming back to the campsite in the form of cute furniture and…
# 0
# ----
# [Announcement]
# Celebrate the first anniversary of #AnimalCrossing: New Horizons with a new installment of the Nook… https://t.co/KypoNuLnH3
# 52414
# ----
# Hi, everyone! Can you believe it's been a full year since Nook Inc. started offering its Deserted Island Getaway Pa… https://t.co/ggYgjd25pX
# 53991
# ----
# [Announcement]
# The latest #AnimalCrossing: New Horizons update is available now! Download the update and make the m… https://t.co/Rw8GCxioiw
# 15977
# ----
# RT @NintendoAmerica: 4/5 is a day for planting trees and caring for our forests called “Singmogil” in South Korea. “Forsythia” can be order…
# 0
# ----
# RT @NintendoAmerica: Nature Day is celebrated around the world on 4/22. On this holiday many show their support for the environment. Inspir…
# 0
# ----
# RT @NintendoAmerica: March 20 marks the 1-year anniversary of #AnimalCrossing: New Horizons. To celebrate, all players who download the lat…
# 0
# ----
# RT @NintendoAmerica: Items inspired by high school Prom will be available in Nook Shopping from 4/1 – 4/30! “Prom Sash”, “Prom Floor” and “…
# 0
# ----
# RT @NintendoAmerica: Looking to play a harmless prank? Nook Shopping has got just the item for you! The Whoopie Cushion item will be availa…
# 0
# ----
# RT @NintendoAmerica: Once you have the Custom Design Pro Editor +, you’ll be able to create custom designs for umbrellas, Uchiwa Fans, hand…
# 0
# ----
# [Announcement]
# Show your island off to the world with the #AnimalCrossing: New Horizons Island Tour Creator. Make d… https://t.co/ZGh85WDYVv
# 12473
# ----
# [Announcement]
# The Nook Link within the #NintendoSwitchOnline app gets an update in late March! You’ll be able to c… https://t.co/WtPLdJPUl2
# 10493
# ----
# [Announcement]
# Bunny Day is back this year on 4/4! Collect a variety of eggs and craft DIY Bunny Day themed items.… https://t.co/snaNVEqvx6
# 8848
# ----
# [Announcement]
# After the update on 3/18, you can add more Pro Design options, and receive 50 more slots in both Cus… https://t.co/tFEZKlOk21
# 15494
# ----
# [Announcement]
# The #AnimalCrossing: New Horizons update arrives 3/18, bringing @Sanrio themed items and residents t… https://t.co/j2RIGguegd
# 28108
# ----
# Well, going by a 24-hour clock, it's now 15:09 on 3/14...and if you don't know what that means, I'll tell you! It's… https://t.co/XeAuqcNzLN
# 18756
# ----
# RT @NintendoAmerica: Kit &amp; Krysta build and race through a #SuperMarioBros course in #AnimalCrossing: New Horizons on this week’s episode o…
# 0
# ----
# RT @buildabear: COMING SOON! Our Animal Crossing™: New Horizons collection is full of fun for all ages. Sign up for free email and text upd…
# 0
# ----
# [Announcement]
# Nintendo's official island, Ninten has been updated to include #SuperMario items on display! Use the… https://t.co/65hDlPfPLs
# 7927
# ----
# [Announcement]
# #ACNH joins #SuperMario35th! Now until 3/24, visit Nintendo's official island to complete the… https://t.co/f9tZrPz6hD
# 5620
# ----
# Hi, friends! Shamrock Day is coming up soon, and I'm already thinking about all the green! I hear that both Nook Sh… https://t.co/Q6QCbaCtb1
# 17146
# ----
# [Video]
# The snow is melting and the grass is getting greener! Here's what you can expect as you march into Spring t… https://t.co/iyiVvNks2v
# 14814
# ----
# RT @NintendoAmerica: Invite some new residents to Photopia on Harv’s Island for a photo shoot! After downloading the update on 3/18, you’ll…
# 0
# ----
# RT @NintendoAmerica: The Shamrock soda, shamrock doorplate, and shamrock rug items will be available from 3/10 to 3/17. One item in the ser…
# 0
# ----
# Happy Hinamatsuri, everyone! This is always one of my favorite events, so I'd love to hear about it if you're doing… https://t.co/CsQeLY3oJf
# 19571
# ----

# %% [markdown]
# And let's create DataFrames for both of them and explore their stats:

# %%
tk_stats = pd.DataFrame({
        "Tiger King Fav":tk_favorites,
        "Tiger King RT":tk_retweets
    })

acnh_stats = pd.DataFrame({
      "ACNH Fav":acnh_favorites,
      "ACNH RT":acnh_retweets
        })

# %%
tk_stats.head()
# Out:
#    Tiger King Fav  Tiger King RT
# 0               0              0
# 1               0              0
# 2              52              7
# 3              18              3
# 4              45              8

# %%
tk_stats.describe()
# Out:
#        Tiger King Fav  Tiger King RT
# count       50.000000      50.000000
# mean        65.080000       6.620000
# std         80.171714      10.607833
# min          0.000000       0.000000
# 25%         23.000000       2.000000
# 50%         46.000000       4.000000
# 75%         72.250000       7.000000
# max        477.000000      68.000000

# %%
acnh_stats.describe()
# Out:
#            ACNH Fav       ACNH RT
# count     50.000000     50.000000
# mean   12030.660000   2026.940000
# std    12412.183709   2327.256389
# min        0.000000    239.000000
# 25%        0.000000    773.000000
# 50%    11505.500000   1298.000000
# 75%    15980.750000   1890.500000
# max    53991.000000  11336.000000

# %% [markdown]
# Now we're plotting the tweets; but we have to sort them first so that they make sense.

# %%
tk_stats = tk_stats.sort_values("Tiger King Fav")
tk_stats = tk_stats.reset_index(drop=True)
tk_stats.head()
# Out:
#    Tiger King Fav  Tiger King RT
# 0               0              0
# 1               0              0
# 2               0             10
# 3               2              1
# 4               7              0

# %%
acnh_stats = acnh_stats.sort_values("ACNH Fav")
acnh_stats = acnh_stats.reset_index(drop=True)
acnh_stats.head(15)
# Out:
#     ACNH Fav  ACNH RT
# 0          0      239
# 1          0     1901
# 2          0    11336
# 3          0     1704
# 4          0     1293
# 5          0     1224
# 6          0     1359
# 7          0     2144
# 8          0     3580
# 9          0      718
# 10         0     2302
# 11         0      670
# 12         0      463
# 13         0      630
# 14         0      489

# %%
combined = acnh_stats.copy()
combined["Tiger King Fav"] = tk_stats["Tiger King Fav"]
combined["Tiger King RT"] = tk_stats["Tiger King RT"]

# %%
combined.plot()
# Out:
# <AxesSubplot:>

# %%
tk_stats.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Exercise

# %% [markdown]
# Retreive the last 50 tweets with the hashtag #datavis in the SLC area, print the text and the username.
