# %%
import pandas as pd

money_df = pd.read_csv("data_banknote.csv", names=["variance", "skewness", "kurtosis", "entropy", "is_real"])
money_df.describe()
# Out:
#           variance     skewness     kurtosis      entropy      is_real
# count  1372.000000  1372.000000  1372.000000  1372.000000  1372.000000
# mean      0.433735     1.922353     1.397627    -1.191657     0.444606
# std       2.842763     5.869047     4.310030     2.101013     0.497103
# min      -7.042100   -13.773100    -5.286100    -8.548200     0.000000
# 25%      -1.773000    -1.708200    -1.574975    -2.413450     0.000000
# 50%       0.496180     2.319650     0.616630    -0.586650     0.000000
# 75%       2.821475     6.814625     3.179250     0.394810     1.000000
# max       6.824800    12.951600    17.927400     2.449500     1.000000

# %%
import seaborn as sb
sb.pairplot(money_df, hue="is_real", plot_kws={'alpha':.5, 's':3})

# %%
from sklearn import metrics
from sklearn.model_selection import train_test_split, cross_val_predict, cross_val_score, KFold

from sklearn import tree

from sklearn.neighbors import NearestNeighbors
from sklearn.neighbors import KNeighborsClassifier

from sklearn.feature_selection import SelectKBest, SelectPercentile, chi2, f_classif

from sklearn import svm
from sklearn.linear_model import LogisticRegression

from matplotlib import pyplot as plt

# %%
df= money_df
predictor_features = df.columns[:-1]
selector = SelectPercentile( f_classif)
                            
x_new = selector.fit_transform(df[predictor_features].values, df.is_real.values)
selector.pvalues_
# Out:
# array([5.74096537e-224, 1.37205114e-067, 6.46552630e-009, 3.85967572e-001])
